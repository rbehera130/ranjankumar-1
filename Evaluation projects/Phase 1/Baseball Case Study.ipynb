# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# #### In this problem we need to predict the wins by analysing the 16 different features of input. So, that will be the target column.

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd    # for handling the dataframe
import numpy as np     # to handle arrays
import matplotlib.pyplot as plt  # data visualisation 
import seaborn as sns    # for data visualisation
import warnings   # to handle unnecessary warnings
warnings.filterwarnings('ignore') # this will ignore the unnecessary warnings

# %%
# loading the dataframe
baseball = pd.read_csv('Baseball_data.csv')

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# Let's do the analysis of data.

# %%
# Checking the shape of dataframe
baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# Here we can see that the dataframe contains 30 rows and 17 columns.

# %%
# let's take overview of the whole data
# as the shape of dataframe is less so we can load the whole dataframe
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Let's see the column names
column = baseball.columns
column
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# #### Data types

# %%
# let's check the data types of the columns
dt = baseball.dtypes
dt
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# From here we can see all columns have numerical data types.

# %% [markdown]
# #### Null Values

# %%
# let's check if any null values in data
null = baseball.isnull().sum()
null
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is not any null value in the dataset.

# %% [markdown]
# #### Statistical Summary

# %%
# let's check the statistical summary of the data
stats = baseball.describe()
stats
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observations:
#
# 1. In the columns H, HR, SV, and E mean is little greater than median that means the data is little right skewed.
# 2. The standard deviation of most columns are high that means data are widely spreaded.
# 3. The difference between 75th percentile and maximimum value are not much big so we can say that there is a very less chance of outliers in the data.

# %% [markdown]
# ### Data visualisation

# %% [markdown]
# #### Correlation

# %%
# checking correlation
corr = baseball.corr()
plt.figure(figsize = (12,8))
sns.heatmap(corr, cmap = 'YlOrRd', annot = True, fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
#     1: Columns ERA, ER and RA are highly negatively correlated with the target column W.
#     2: Columns SV, SHO, BB, 2B, and R are highly positively correlated with the target column W.
#     3: Rest columns are moderately correlated with the target column.
#     4: The independent columns H and AB, HR and R, 2B and R, 2B and H are positively correlated with each other.
#     5: Columns ER and RA, ERA and RA, ERA and ER are highly positively correlated with each other.
#     6: From the above obeservations we can say that there is multicollinearity exist in the dataset.

# %% [markdown]
# #### Distribution of data

# %%
# first let's check the distribution of the data in each column
# let's create a list of all columns
col = list(baseball.columns)
# now we will use for loop to plot every column and we will use histplot to see the distribution of the data in each column
for i in col:
    plt.title(i)
    sns.histplot(baseball[i], kde = True)
    plt.show()

# %% [markdown]
# Observation:
#
#     1: From the above visualisation we can easily see that data are normally distributed in most of the columns.
#     2: There are few columns which have slightly right skewed data.

# %% [markdown]
# #### Outliers

# %%
# Now we will check for outliers present in data
# we will use boxplot to check it

# as we have already made a list of all column and stored that in a variable name col we will use that here

# we will use for loop to plot all graph
for i in col:
    plt.xlabel(i)
    plt.boxplot(baseball[i])
    plt.show()

# %% [markdown]
# Observation:
#
#     1: By Visualising all the boxplot we can see that there are no outliers present in most of the columns data.
#     2: Column R, ERA, SHO, SV, and E contains very few outlier we will try to handle them.

# %% [markdown]
# #### Relationship between dependent and independent variables

# %%
# let's check the relation of our dependent variable with all other independent variables.
# first we will make a list of all independent variables
independent = col[1:]
# here we have already make a list of all the columns and holded it into col variable and our dependent variable is 'W'
# and that is on first index of that list i.e. 0 so, we made a list where we didn't take that index so now in this list
# we have only independent variables

# to check the relationship between them we will use regplot
# we will use a for loop to plot all the graphs
for i in independent:
    print('Relationship between W and',i)
    plt.xlabel('W')
    plt.ylabel(i)
    sns.regplot(x = baseball['W'], y = i, data = baseball)
    plt.show()
# Out:
# Relationship between W and R
# Relationship between W and AB
# Relationship between W and H
# Relationship between W and 2B
# Relationship between W and 3B
# Relationship between W and HR
# Relationship between W and BB
# Relationship between W and SO
# Relationship between W and SB
# Relationship between W and RA
# Relationship between W and ER
# Relationship between W and ERA
# Relationship between W and CG
# Relationship between W and SHO
# Relationship between W and SV
# Relationship between W and E

# %% [markdown]
# Observations:
#
#     1: Columns 2B, BB, SHO and SV are highly positively correlated with the target columns i.e. win.
#     2: Columns R and HR are moderately correlated with target column.
#     3: RA, ER and ERA are highly negatively correlated with our target column that means if they will increase the
#        number of wins will decrease.
#     4: 3B, SB, and E are moderately negative correlated with the target column.
#     5: AB, H, SO, and CG are showing somewhere similar to linear relationship with win.

# %% [markdown]
# #### Relationship between two independent variables

# %%
# From correlation we have seen that there are several independent variables that are highly positively correlated with each 
# other so now we will check the relationship between those independent variable.

# we will use regplot for it and check it one by one

# checking the relationship between ER and RA
plt.title('Relation between ER and RA')
plt.xlabel('ER')
plt.ylabel('RA')
sns.regplot(x = baseball['ER'], y = baseball['RA'], data = baseball)
plt.show()

# %%
# checking relationship between ERA and RA 
plt.title('Relation between ERA and RA')
plt.xlabel('ERA')
plt.ylabel('RA')
sns.regplot(x = baseball['ERA'], y = baseball['RA'], data = baseball)
plt.show()

# %%
# relationship between ERA and ER
plt.title('Relation between ERA and ER')
plt.xlabel('ERA')
plt.ylabel('ER')
sns.regplot(x = baseball['ERA'], y = baseball['ER'], data = baseball)
plt.show()

# %%
# relationship between H and AB
plt.title('Relation between H and AB')
plt.xlabel('H')
plt.ylabel('AB')
sns.regplot(x = baseball['H'], y = baseball['AB'], data = baseball)
plt.show()

# %%
# relation between HR and R
plt.title('Relation between HR and R')
plt.xlabel('HR')
plt.ylabel('R')
sns.regplot(x = baseball['HR'], y = baseball['R'], data = baseball)
plt.show()

# %% [markdown]
# Observation: From the above visualisation of graphs we can see that there is highly multicollinearity exist between columns ER and RA, ERA and RA, ERA and ER. We need to handle the multicollinearity otherwise the model will not be able to understand that which input data adds more weight to the output.

# %% [markdown]
# ### Feature Engineering

# %%
# first let's make a copy of the dataset and we will do all the feature engineering on this
baseball_copy = baseball.copy()

# %%
# Let's split out input and target data 
# we will hold input data into variable x and output data into variable y
x = baseball_copy.iloc[ : , 1:]
y = baseball_copy.iloc[ : , 0]

# %%
# let's check shape of our input and output data
print(x.shape)
print(y.shape)
# Out:
# (30, 16)
# (30,)

# %% [markdown]
# We will perform all the feature engineering on the input data only.

# %% [markdown]
# #### Outlier

# %%
# importing library to check the zscore of data
from scipy.stats import zscore

# %%
# checking zscore
z = np.abs(zscore(x))
# here np.abs is used so it will show absolute i.e. positive zscore value of every data

# %%
# as we know the data which is outer from 3 standard deviation is known as outlier so we have taken threshold value 3
threshold = 3
np.where(z>threshold)
# here we are checking which data zscore value is greater than 3
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %% [markdown]
# Here first array is showing row number and 2nd array is showing column number which zscore value is greater than 3.
#
# As it is showing only one data so that mean the dataset have only one outlier.

# %%
# let's check it
z.iloc[5,0]
# Out:
# 3.5096470447193067

# %% [markdown]
# Here we can see it is 3.50 that means it is outer from 3 standard deviation.

# %% [markdown]
# As we have seen there is only one outlier so we will not delete that because as our dataset is small and to remove this outlier we need to drop whole row and then there will be data loss. We will train our model then check it if there will be any problem from this outlier then only we will remove it.

# %% [markdown]
# #### Multicollinearity

# %% [markdown]
# We have seen there are several independent columns which have equal contribution to the model because of this the model will not be able to understand that which variable is giving more weightage so we will try to handle this situation of multicollinearity.

# %%
# importing library to calculate VIF (Variance Inflation Factor)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# we will make a user defined function and use for loop to pass one by one column of input data to calculate vif value
def vif():
    vif = pd.DataFrame()
    # here we have made an empty dataframe with name vif
    
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    # it will calculate the vif value of every column of input data and add it into the empty dataframe column VIF Factor
    # here x.shape[1] is given because we need to calculate the vif value of columns only
    # with the help of vif values we will be able to understand that which column data is providing more weightage to the output
    # so we can drop one or two columns with multicollinearity between them.
    
    vif['Features'] = x.columns
    # this will add a new column named Features into the dataset
    
    print(vif)
    # printing the dataframe to check the VIF values of different columns of input data.

# %%
vif()
# Out:
#       VIF Factor Features
# 0    1638.985029        R
# 1    4277.157018       AB
# 2    4698.798408        H
# 3     904.439835       2B
# 4      32.435486       3B
# 5     285.773237       HR
# 6     269.485018       BB
# 7     398.234104       SO
# 8      28.654970       SB
# 9   17204.829356       RA
# 10  49837.289228       ER
# 11  23551.544014      ERA
# 12      6.771036       CG
# 13     30.276598      SHO
# 14    119.686080       SV
# 15     94.215202        E

# %% [markdown]
# As we know that RA, ER and ERA have very high multicollinearity but from this VIF value we can see that RA and ERA columns are giving very less weightage to the model prediction. So, we will drop these two columns.

# %%
# dropping RA and ERA columns
baseball_copy.drop(['RA','ERA'],axis = 1, inplace = True)

# %%
baseball_copy.shape
# Out:
# (30, 15)

# %% [markdown]
# Here we can see two columns are dropped

# %%
# Let's check the dataframe
baseball_copy.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   ER  CG  SHO  SV    E
# 0  95  724  5575  1497  300  42  139  383   973  104  601   2    8  56   88
# 1  83  696  5467  1349  277  44  156  439  1264   70  653   2   12  45   86
# 2  81  669  5439  1395  303  29  141  533  1157   86  584  11   10  38   79
# 3  76  622  5533  1381  260  27  136  404  1231   68  643   7    9  37  101
# 4  74  689  5605  1515  289  49  151  455  1259   83  746   7   12  35   86

# %% [markdown]
# From here we can see our RA and ERA Columns are dropped

# %% [markdown]
# #### Scaling

# %% [markdown]
# As we can see our data is not scaled so let's scale it so that all data will be on same scale and model can learn well.

# %%
# before that we will split our data into input and target. We will hold input data in variable x and target in y.
x = baseball_copy.iloc[ : , 1: ]
y = baseball_copy.iloc[ : , 0]

# %%
# now we will use min_max scaler and scale only input data
# importing required library
from sklearn.preprocessing import MinMaxScaler

# holding this library into an instance
mms = MinMaxScaler()

# %%
# applying scaling to the input data
min_max = mms.fit_transform(x)

# %% [markdown]
# Now the data is scaled. But this will be in numpy array format so we need to convert it into pandas dataframe.

# %%
# converting the scaled data into pandas dataframe
x_input = pd.DataFrame(min_max)

# %%
# let's check scaled data
x_input.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.474843  0.719697  0.905759  0.888889  0.805556  0.295455  0.041026
# 1  0.386792  0.310606  0.130890  0.569444  0.861111  0.424242  0.328205
# 2  0.301887  0.204545  0.371728  0.930556  0.444444  0.310606  0.810256
# 3  0.154088  0.560606  0.298429  0.333333  0.388889  0.272727  0.148718
# 4  0.364780  0.833333  1.000000  0.736111  1.000000  0.386364  0.410256
#
#          7         8         9         10        11        12        13
# 0  0.000000  0.666667  0.383178  0.181818  0.235294  0.823529  0.254902
# 1  0.533945  0.288889  0.545171  0.181818  0.470588  0.500000  0.215686
# 2  0.337615  0.466667  0.330218  1.000000  0.352941  0.294118  0.078431
# 3  0.473394  0.266667  0.514019  0.636364  0.294118  0.264706  0.509804
# 4  0.524771  0.433333  0.834891  0.636364  0.470588  0.205882  0.215686

# %% [markdown]
# Here we can see now all values of input data is scaled between 0 to 1.

# %% [markdown]
# ### Now the data is ready to go for model training.

# %% [markdown]
# ### Data Splitting and Model building

# %% [markdown]
# As we have split the input and target data and do the feature engineering into the input data now it's time to split data for training, testing and Model building.

# %%
# first we need to import required libraries
# for splitting the data into training and testing
from sklearn.model_selection import train_test_split

import sklearn   # this is machine learning library

# as this is a regression problem so importing some regression models for training then select the best model
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# making an instance of models
lr = LinearRegression()
svr = SVR()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# metrics for model performance
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# splitting data for training and testing
# we will use for loop to split data to select best random state
for i in range(40,61):
    x_train, x_test, y_train, y_test = train_test_split(x_input, y, test_size = 0.20, random_state = i)
    # this will split 80% data for training and 20% data for testing from random state 40 to 60 one by one
    
    lr.fit(x_train,y_train)
    # sending training data to the model one by one
    
    pred_train = lr.predict(x_train)
    # making predicting of training data
    
    pred_test = lr.predict(x_test)
    # making predicting of testing data
    
    print('At random state',i,'Training accuray is:',r2_score(y_train,pred_train))
    print('At random state',i,'Testing accuray is:',r2_score(y_test,pred_test), '\n')
# Out:
# At random state 40 Training accuray is: 0.9586295906603054
# At random state 40 Testing accuray is: 0.6003274572598403
#
# At random state 41 Training accuray is: 0.9488074422032853
# At random state 41 Testing accuray is: 0.7751588893723432
#
# At random state 42 Training accuray is: 0.9651196029510228
# At random state 42 Testing accuray is: 0.7655609732745527
#
# At random state 43 Training accuray is: 0.9763113029566356
# At random state 43 Testing accuray is: -0.15002695128985932
#
# At random state 44 Training accuray is: 0.9494640586855201
# At random state 44 Testing accuray is: 0.7103613978659483
#
# At random state 45 Training accuray is: 0.9388529259908975
# At random state 45 Testing accuray is: 0.905264701981393
#
# At random state 46 Training accuray is: 0.94827251287703
# At random state 46 Testing accuray is: 0.7382872855083236
#
# At random state 47 Training accuray is: 0.9388697355534232
# At random state 47 Testing accuray is: 0.9045782106833059
#
# ...

# %% [markdown]
# From this observation we can see at random state 45 and 47 the model is giving the best training and testing accuray.

# %%
# select random state 45 as model is giving best accuracy at that state and splitting the data
x_train, x_test, y_train, y_test = train_test_split(x_input, y, test_size = 0.20, random_state = 45)

# %% [markdown]
# Data is splitted into training and testing at best random state and ready to go for training

# %%
# making a list of all models
models = [lr, svr, dt, knn]

# we will use for loop to train all models one by one and evaluate them
for model in models:
    # sending training data to the different models one by one
    model.fit(x_train,y_train)
    
    # making prediction
    pred = model.predict(x_test)
    
    # Evaluating the model
    print('Evaluation of', model, ':')
    print('r2_score:',r2_score(y_test, pred))
    print('Mean squared error:', mean_squared_error(y_test, pred))
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
    print('\n')
# Out:
# Evaluation of LinearRegression() :
# r2_score: 0.905264701981393
# Mean squared error: 6.978833620704054
# Mean absolute error: 2.4193501079100748
# Root mean squared error: 2.641748212965054
#
#
# Evaluation of SVR() :
# r2_score: -0.3093138546272367
# Mean squared error: 96.4527872908731
# Mean absolute error: 7.9670011506765634
# Root mean squared error: 9.821037994574358
#
#
# Evaluation of DecisionTreeRegressor() :
# r2_score: 0.27828054298642535
# Mean squared error: 53.166666666666664
# Mean absolute error: 6.166666666666667
# Root mean squared error: 7.291547618075786
#
#
# Evaluation of KNeighborsRegressor() :
# r2_score: 0.2580090497737558
# Mean squared error: 54.65999999999999
# Mean absolute error: 6.433333333333333
# Root mean squared error: 7.393240155709808

# %% [markdown]
# From here we can see the r2 score of only LinearRegression model is quite good over all other models. But we can't rely only this because it can be possible because of model overfitting. We will check that but we will go ahead with LinearRegression model.

# %%
# let's train LinearRegression model first
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_train = lr.predict(x_train)
# making predicting of training data
    
pred_test = lr.predict(x_test)
# making prediction of testing data

train_accuracy = r2_score(y_train, pred_train)
# checking training accuracy from r2 score

test_accuracy = r2_score(y_test, pred_test)
# checking testing accuracy from r2 score

print('Training accuracy is:', train_accuracy, 'and Testing accuracy is:', test_accuracy)
# Out:
# Training accuracy is: 0.9388529259908975 and Testing accuracy is: 0.905264701981393

# %% [markdown]
# As we know r2 score tells us how well our model is fitted on data. That means if it is around 100% then we can say that it is best fitted. Here r2 score of test data is around 90% so, we can say that it is fitting very well.

# %% [markdown]
# #### Cross validation

# %%
# importing library
from sklearn.model_selection import cross_val_score

# %%
# we will use for loop to check cross validation score at different values
for i in range(3,9):
    score = cross_val_score(lr, x_input, y, cv = i)
    mean_score = score.mean()
    print('At Cross Fold', i, 'Cross validation score is:', mean_score,'\n')
# Out:
# At Cross Fold 3 Cross validation score is: 0.21248588046424124
#
# At Cross Fold 4 Cross validation score is: 0.6813070183719092
#
# At Cross Fold 5 Cross validation score is: 0.3488501123223915
#
# At Cross Fold 6 Cross validation score is: 0.4062187767866498
#
# At Cross Fold 7 Cross validation score is: 0.4803470982431842
#
# At Cross Fold 8 Cross validation score is: 0.47724336997131134

# %% [markdown]
# Here we can see that the CV score is not much improved, higher CV is at Cross fold 4 but that is less from our accuracy.

# %%
# Let's check how well our line is fitting to the test data
plt.scatter(x = y_test, y = pred_test, color = 'r')
plt.plot(y_test, y_test, color = 'b')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('LinearRegression')
plt.plot()
# Out:
# []

# %% [markdown]
# This is our best fit line of the model.

# %% [markdown]
# #### Regularization and Hyperparameter tuning

# %%
# importing libraries
from sklearn.model_selection import GridSearchCV
# this is used to perform hyperparameter tuning

from sklearn.linear_model import Lasso
# we will use Lasso model for regularization

# %%
# making dictionary of different parameters to check the score for different parameters and find the best parameter
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1], 'random_state': list(range(10))}

# making instance of lasso
ls = Lasso()

# making instance to perform hyperparameter tuning
ht = GridSearchCV(ls, parameters)

# sending data to check best parameter
ht.fit(x_train, y_train)

# checking best parameter
print(ht.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %% [markdown]
# Here it has given us the best fit parameters to train our model.

# %% [markdown]
# We will train our model according to this parameter

# %%
# final model training
la = Lasso(alpha = 0.1, random_state = 0)

# sending data for training
la.fit(x_train, y_train)

# checking training score
la_training_score = la.score(x_test, y_test)

# making prediction
la_pred = la.predict(x_test)

# printing training accuracy
print('Training accuracy:', (la_training_score)*100)

# printing testing accuracy
print('Testing accuracy:', (r2_score(y_test, la_pred))*100)
# Out:
# Training accuracy: 90.22993458446203
# Testing accuracy: 90.22993458446203

# %% [markdown]
# Here we can see that both training and testing data are giving similar accuracy that means our model is not overfitting.

# %%
# checking cross validation score
cv_score = cross_val_score(la, x_input, y, cv = 4)
mean = cv_score.mean()
mean*100
# Out:
# 83.36905964199181

# %% [markdown]
# From here we can see that the difference between Testing accuracy and Cross Validation score has also decreases now our model will work much better than earlier.

# %%
# let's check some other error metrics
print('Mean squared error:', mean_squared_error(y_test, la_pred))
print('Mean absolute error:',mean_absolute_error(y_test, la_pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test, la_pred)))
# Out:
# Mean squared error: 7.197281522779643
# Mean absolute error: 2.2972338960767167
# Root mean squared error: 2.6827749668542165

# %% [markdown]
# Here we can see that errors are also some decreases.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We have checked all the error metrics done the hyperparameter tuning and after doing all these our model has achieved maximum 90% accuracy.
#
# So, now we will save this model.

# %% [markdown]
# ### Saving the model

# %%
import pickle

# %%
filename = 'Baseball.pkl'
pickle.dump(la, open(filename, 'wb'))

# %% [markdown]
# ### Loading the model

# %%
load_model = pickle.load(open('Baseball.pkl', 'rb'))
result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 90.22993458446203

# %% [markdown]
# Here we can see the accuracy of model.

# %%
# Let's see the predictions made by our model in dataframe
pd.DataFrame([load_model.predict(x_test)[:], y_test[:]],index = ['Predicted', 'Original'])
# Out:
#                    0          1          2          3          4          5
# Predicted  93.134343  81.530055  89.620071  93.209084  78.203587  79.595091
# Original   98.000000  79.000000  92.000000  93.000000  76.000000  78.000000

# %% [markdown]
# Here we can see there is not too much difference between original value and predicted value of the model. So, we can say that our model is working extremely well.
