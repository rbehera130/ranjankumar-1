# %% [markdown]
# # Cause of Death : Analysis of Data

# %% [markdown]
# There is a collection of data which contains historical data of different cause of death for all ages around the world. We have to do complete analysis of data to give findings and conclusion.

# %%
# importing required libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataset
data = pd.read_csv(r"C:\Users\sonus\Downloads\Cause-of-Death--1-\archive\cause_of_deaths dataset.csv")

# %%
# loading top 5 rows of dataset
data.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
# checking shape of it
data.shape
# Out:
# (6120, 34)

# %% [markdown]
# it contains 6120 rows and 34 columns

# %%
# checking other information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
# checking for null values if any
data.isnull().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %% [markdown]
# There is no any null values present in dataset

# %%
# finding unique value of country column
unique = data['Country/Territory'].unique()
# checking total number of country
len(unique)
# Out:
# 204

# %% [markdown]
# we have 204 countries data

# %%
# checking statistical summary of data
statistical_summary = data.describe()
statistical_summary.iloc[ : , 0:10]
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
statistical_summary.iloc[ : , 10:20]
# Out:
#        Drug Use Disorders   Tuberculosis  Cardiovascular Diseases  \
# count         6120.000000    6120.000000             6.120000e+03
# mean           434.006699    7491.928595             7.316045e+04
# std           2898.761628   39549.977578             2.915775e+05
# min              0.000000       0.000000             4.000000e+00
# 25%              3.000000      35.000000             2.028000e+03
# 50%             20.000000     417.000000             1.174200e+04
# 75%            129.000000    2924.250000             4.254650e+04
# max          65717.000000  657515.000000             4.584273e+06
#
#        Lower Respiratory Infections  Neonatal Disorders  \
# count                   6120.000000         6120.000000
# mean                   13687.914706        12558.942647
# std                    48031.720009        56058.366412
# min                        0.000000            0.000000
# 25%                      345.000000          131.000000
# ...

# %%
statistical_summary.iloc[ : , 20:]
# Out:
#           Neoplasms  Conflict and Terrorism  Diabetes Mellitus  \
# count  6.120000e+03             6120.000000        6120.000000
# mean   3.754224e+04              538.243954        5138.704575
# std    1.615584e+05             7033.308187       16773.081040
# min    1.000000e+00                0.000000           1.000000
# 25%    8.097500e+02                0.000000         236.000000
# 50%    5.629500e+03                0.000000        1087.000000
# 75%    2.014775e+04               23.000000        2954.000000
# max    2.716551e+06           503532.000000      273089.000000
#
#        Chronic Kidney Disease    Poisonings  Protein-Energy Malnutrition  \
# count             6120.000000   6120.000000                  6120.000000
# mean              4724.132680    425.013399                  1965.994281
# std              16470.429969   2022.640521                  8255.999063
# min                  0.000000      0.000000                     0.000000
# ...

# %% [markdown]
# Observations:
#
#     1. Average about 12550 people died every year due to Neonatal Disorders.
#
#     2. Highest number of deaths due to Neonatal Disorders in a year is 852761.
#
#     3. There are certain more disease due to which highest number of people dies every year they are like, Tuberculosis, Lo-wer Respiratory Infections, HIV/AIDS, Digestive Disease etc.
#
#     4. Highest number of people died due to Conflict and Terrorism in a year is 503532 this is very huge. May be these peop-le does't have any disease.
#
#     5. Average 5930 peolple dies every year in Road Injuries.
#
#     6. Very less people dies due to poision every year.
#
#     7. Average around 250 people dies every year due to Nature either Exposure to Force or Heat and Cold Exposure.

# %%
# checking correlation between data using heatmap
corr = data.corr()
plt.figure(figsize = (20,15))
sns.heatmap(corr, annot = True, cmap = 'YlOrRd')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
#     Highly Positive Correlation:
#
#         1. Parkinson's Diseases with Alzheimer's Disease and Othe Dementias
#
#         2. Lower Respiratory infections and Neonatal Disorders with Tuberculosis
#
#         3. Neonatal Disorder with lower Respiratory Infection
#
#         4. Chronic Respiratory Disease with Road Injuries
#
#         5. Digestive Diseases with Cirrhosis and other Chronic liver Diseases
#
#    Ther are not any negative correlation between columns

# %% [markdown]
# ## Univariate analysis

# %%
# checking column names and total number of columns
print(data.columns)
print(len(data.columns))
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')
# 34

# %%
# as our dataset contains 34 columns so it will be difficult and lenthy process to plot every column one by one for univariate
# analysis so holding columns in a list we will use for loop to plot graphs.

columns = list(data.columns)

# %%
# as out first 3 columns contains name, code and year so plotting every column after them

# using for loop for univariate analysis it will plot one by one every column data 
# using area plot for univariate analysis it will make easy to understand this data.
for i in columns[3:]:
    print('No. of people dies due to',i,':',data[i].sum())
    # This will print total number of people dies in different countries over 30 years span due to different diseases
    
    plt.title(i)
    data[i].plot.area()
    plt.show()
# Out:
# No. of people dies due to Meningitis : 10524572
# No. of people dies due to Alzheimer's Disease and Other Dementias : 29768839
# No. of people dies due to Parkinson's Disease : 7179795
# No. of people dies due to Nutritional Deficiencies : 13792032
# No. of people dies due to Malaria : 25342676
# No. of people dies due to Drowning : 10301999
# No. of people dies due to Interpersonal Violence : 12752839
# No. of people dies due to Maternal Disorders : 7727046
# No. of people dies due to HIV/AIDS : 36364419
# No. of people dies due to Drug Use Disorders : 2656121
# No. of people dies due to Tuberculosis : 45850603
# No. of people dies due to Cardiovascular Diseases : 447741982
# No. of people dies due to Lower Respiratory Infections : 83770038
# No. of people dies due to Neonatal Disorders : 76860729
# No. of people dies due to Alcohol Use Disorders : 4819018
# No. of people dies due to Self-harm : 23713931
# No. of people dies due to Exposure to Forces of Nature : 1490132
# ...

# %% [markdown]
# Observations:
#
#     Highest number of people dies due to Cardiovascular Disease.
#
#     Forces of Nature played least role to people death.
#
#     Digestive, Chronic Respiratory, Neoplasms, Diarrheal, Neonatal, Lower Respiratory Infections, these diseases are the reasons due to which most number of people died.
#
#     Parkinson, Maternal Disorders, Drug use Disorders, Alcohol use Disorders, Conflict and Terrorism, Poisonings, Fire Heat and Hot Substances, Acute Hepatitis these are the least factors of death of people.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Let's check the diseases which cause most and least number of people death

# %%
# As our dataset is big so making empty lists for death count and disease, using for loop to find and adding total number of 
# deaths due to every disease then making a dictionary using them so that we can make a dataframe of that and plot it on graph
# for analysis purpose

disease = columns[3:]  # adding disease names in list
total_deaths = []
for i in columns[3:]:
    total_deaths.append(data[i].sum())  # finding total death count and adding it into list
    
# making dictionary of disease and death counts
total_figure = {'Disease': disease, 'Total_deaths': total_deaths}

# %%
# making dataframe of our dictionary
death_counts = pd.DataFrame(total_figure)

# checking top 5 rows of our dataframe
death_counts.head()
# Out:
#                                    Disease  Total_deaths
# 0                               Meningitis      10524572
# 1  Alzheimer's Disease and Other Dementias      29768839
# 2                      Parkinson's Disease       7179795
# 3                 Nutritional Deficiencies      13792032
# 4                                  Malaria      25342676

# %%
# our data is ready now we can plot it into graph but before that we will sort our data in descending number of death counts
# so that we will get the disease due to which highest and lowest number of people are dead
sorted_frame = death_counts.sort_values(by = 'Total_deaths', ascending = False)

# now or dataframe is sorted in descending number of death counts

# %%
# finding top 10 disease due to which most number of people dies
plt.figure(figsize = (15,10))
plt.title('Top death cause')
sns.barplot(x = "Total_deaths", y = 'Disease', data = sorted_frame.iloc[ :10, :], orient = "h")
plt.show()

# %% [markdown]
# These are the top 10 disease due to which most number of people died in all countries.

# %%
# finding top 10 disease which are the least factors of people death
plt.figure(figsize = (15,10))
plt.title('Least death cause')
sns.barplot(x = "Total_deaths", y = 'Disease', data = sorted_frame.iloc[-10:, :], orient = "h")
plt.show()

# %% [markdown]
# These are least 10 factors of people death.

# %% [markdown]
# ### Let's check countries with high and low number of deaths

# %%
# first let's group countries because these contains data year by year
countries_deaths = data.groupby('Country/Territory').sum()

# %%
# we don't need year column so let's drop it
countries_deaths.drop('Year', axis = 1, inplace = True)

# %%
# adding countries name in a list
countries = list(countries_deaths.index)

# %%
# now making an empty list to add total number of death in every country
total_deaths_in_country = []

# using for loop to find total death and adding it into the list
for i in countries:
    al = countries_deaths.loc[i,:].sum()
    total_deaths_in_country.append(al)
    
# making dictionary of country name and total number of deaths
country_data = {'Country':countries, 'Deaths':total_deaths_in_country}

# passing it into dataframe
country_df = pd.DataFrame(country_data)

# sorting data in descending order of death counts
sorted_country_df = country_df.sort_values(by = 'Deaths', ascending = False)

# %%
# let's check top 20 countries with highest number of deaths
plt.figure(figsize = (15,10))
plt.title('Countries with highest death counts')
sns.barplot(x = 'Deaths', y = 'Country', data = sorted_country_df.iloc[:20, :], orient = 'h')
plt.show()

# %% [markdown]
# Most number of death people are from these top 20 countries.

# %%
# let's check 10 countries with least number of deaths
plt.figure(figsize = (15,10))
plt.title('Countries with least death counts')
sns.barplot(x = 'Deaths', y = 'Country', data = sorted_country_df.iloc[-10:, :], orient = 'h')
plt.show()

# %% [markdown]
# There are least people from these countries

# %% [markdown]
# ### let's check countries with most and least death due to particular disease

# %%
# first let's add all causes in a list
causes = list(countries_deaths.columns)

# %%
# calling our dataframe which we already have with total death counts due to every cause of every country
df = countries_deaths

# %%
# using for loop to sort every cause death numbers and plot top 10 countries of death numbers due to every cause
for i in causes:
    sor = countries_deaths.loc[:,i].sort_values(ascending = False)
    d = pd.DataFrame(sor)
    d.reset_index(inplace = True)
    print('Top 10 countries with most number of deaths due to',i)
    sns.barplot(x = i, y = 'Country/Territory', data = d.iloc[:10,:])
    plt.show()
# Out:
# Top 10 countries with most number of deaths due to Meningitis
# Top 10 countries with most number of deaths due to Alzheimer's Disease and Other Dementias
# Top 10 countries with most number of deaths due to Parkinson's Disease
# Top 10 countries with most number of deaths due to Nutritional Deficiencies
# Top 10 countries with most number of deaths due to Malaria
# Top 10 countries with most number of deaths due to Drowning
# Top 10 countries with most number of deaths due to Interpersonal Violence
# Top 10 countries with most number of deaths due to Maternal Disorders
# Top 10 countries with most number of deaths due to HIV/AIDS
# Top 10 countries with most number of deaths due to Drug Use Disorders
# Top 10 countries with most number of deaths due to Tuberculosis
# Top 10 countries with most number of deaths due to Cardiovascular Diseases
# Top 10 countries with most number of deaths due to Lower Respiratory Infections
# ...

# %% [markdown]
# Observation: India, China and certain more countries have most number of death due to most of the disease

# %%
# using for loop to sort every cause death numbers and plot top 10 countries of death numbers due to every cause
for i in causes:
    sor = countries_deaths.loc[:,i].sort_values()
    d = pd.DataFrame(sor)
    d.reset_index(inplace = True)
    print('Countries with least number of deaths due to',i)
    sns.barplot(x = i, y = 'Country/Territory', data = d.iloc[:10,:])
    plt.show()
# Out:
# Countries with least number of deaths due to Meningitis
# Countries with least number of deaths due to Alzheimer's Disease and Other Dementias
# Countries with least number of deaths due to Parkinson's Disease
# Countries with least number of deaths due to Nutritional Deficiencies
# Countries with least number of deaths due to Malaria
# Countries with least number of deaths due to Drowning
# Countries with least number of deaths due to Interpersonal Violence
# Countries with least number of deaths due to Maternal Disorders
# Countries with least number of deaths due to HIV/AIDS
# Countries with least number of deaths due to Drug Use Disorders
# Countries with least number of deaths due to Tuberculosis
# Countries with least number of deaths due to Cardiovascular Diseases
# Countries with least number of deaths due to Lower Respiratory Infections
# Countries with least number of deaths due to Neonatal Disorders
# Countries with least number of deaths due to Alcohol Use Disorders
# ...

# %% [markdown]
# Observations: There are certain disease due to which there is not any death occurs in certain countries.

# %% [markdown]
# ### Let's check death by year

# %%
# adding years in list
year = list(data.Year.unique())

# making dataframe by year group
year_data = data.groupby('Year').sum()

# making empty list to add total number of death in every year in list
total_death_in_year = []

# using for loop to find total number of deaths in every year and adding them into list
for i in year:
    total = year_data.loc[i,:].sum()
    total_death_in_year.append(total)

# %%
# making dictionary of year and death 
year_death = {'Year':year, 'No. of Death':total_death_in_year}

# making dataframe of dictionary
df1 = pd.DataFrame(year_death)

# %%
# plotting data into graph
plt.figure(figsize = (15,10))
sns.lineplot(x = 'Year', y = 'No. of Death', data = df1, marker = 'o')
plt.show()

# %% [markdown]
# ### Let's check most death cause disease in every year

# %%
# let's convert rows into columns and vice vers of our dataframe year_data
df2 = year_data.transpose()

# adding different years into a list
year = list(df2.columns)

# %%
# using for loop to find every year data and plotting them into graph
for i in year:
    sort = df2.loc[ : ,i].sort_values(ascending = False)
    s = pd.DataFrame(sort)
    s.reset_index(inplace = True)
    print('Top 15 death cause in year',i)
    sns.barplot(x = i, y = 'index', data = s.iloc[ :15 ,])
    plt.show()
# Out:
# Top 15 death cause in year 1990
# Top 15 death cause in year 1991
# Top 15 death cause in year 1992
# Top 15 death cause in year 1993
# Top 15 death cause in year 1994
# Top 15 death cause in year 1995
# Top 15 death cause in year 1996
# Top 15 death cause in year 1997
# Top 15 death cause in year 1998
# Top 15 death cause in year 1999
# Top 15 death cause in year 2000
# Top 15 death cause in year 2001
# Top 15 death cause in year 2002
# Top 15 death cause in year 2003
# Top 15 death cause in year 2004
# Top 15 death cause in year 2005
# Top 15 death cause in year 2006
# Top 15 death cause in year 2007
# Top 15 death cause in year 2008
# Top 15 death cause in year 2009
# Top 15 death cause in year 2010
# Top 15 death cause in year 2011
# Top 15 death cause in year 2012
# Top 15 death cause in year 2013
# Top 15 death cause in year 2014
# Top 15 death cause in year 2015
# Top 15 death cause in year 2016
# Top 15 death cause in year 2017
# Top 15 death cause in year 2018
# ...

# %% [markdown]
# Observation: After analysing every graph we can say that there are certain disease which are the factor of most death in most of the years.

# %% [markdown]
# ### least death cause disease in every year.

# %%
# using for loop to find every year data and plotting them into graph
for i in year:
    sort = df2.loc[ : ,i].sort_values()
    s = pd.DataFrame(sort)
    s.reset_index(inplace = True)
    print('Least death cause disease in year',i)
    sns.barplot(x = i, y = 'index', data = s.iloc[ :15 ,])
    plt.show()
# Out:
# Least death cause disease in year 1990
# Least death cause disease in year 1991
# Least death cause disease in year 1992
# Least death cause disease in year 1993
# Least death cause disease in year 1994
# Least death cause disease in year 1995
# Least death cause disease in year 1996
# Least death cause disease in year 1997
# Least death cause disease in year 1998
# Least death cause disease in year 1999
# Least death cause disease in year 2000
# Least death cause disease in year 2001
# Least death cause disease in year 2002
# Least death cause disease in year 2003
# Least death cause disease in year 2004
# Least death cause disease in year 2005
# Least death cause disease in year 2006
# Least death cause disease in year 2007
# Least death cause disease in year 2008
# Least death cause disease in year 2009
# Least death cause disease in year 2010
# Least death cause disease in year 2011
# Least death cause disease in year 2012
# Least death cause disease in year 2013
# ...

# %% [markdown]
# These graphs are also showing similar tendency
